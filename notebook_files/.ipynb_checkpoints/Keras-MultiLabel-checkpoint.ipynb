# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.random.seed(42)

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
df_train = pd.read_csv("output_files/combined.csv", index_col=0)

# %%
df_train.head()
# Out:
#    ART_CODE                              DESC_CODED  \
# 0         0                           Hyponatraemia
# 1         1  Subacute cutaneous lupus erythematosus
# 2         2  Blood bilirubin unconjugated increased
# 3         3              toxic epidermal necrolysis
# 4         4                             Bradycardia
#
#                             HLGT_NAME_COMPL                 HLT_NAME_COMPL  \
# 0  ELECTROLYTE AND FLUID BALANCE CONDITIONS               SODIUM IMBALANCE
# 1           EPIDERMAL AND DERMAL CONDITIONS    CONNECTIVE TISSUE DISORDERS
# 2              HEPATOBILIARY INVESTIGATIONS        LIVER FUNCTION ANALYSES
# 3           EPIDERMAL AND DERMAL CONDITIONS             BULLOUS CONDITIONS
# 4                       CARDIAC ARRHYTHMIAS  RATE AND RHYTHM DISORDERS NEC
#
#      INC_CODE  INC_CODE_J                          LLT_NAME_COMPL  \
# 0  10021038.0    10021036                            HYPONATREMIA
# 1  10057903.0    10057903  SUBACUTE CUTANEOUS LUPUS ERYTHEMATOSUS
# 2  10021709.0    10021709            INDIRECT BILIRUBIN INCREASED
# 3  10044223.0    10044223              TOXIC EPIDERMAL NECROLYSIS
# 4  10006093.0    10006093                             BRADYCARDIA
#
#                             PT_NAME_COMPL  \
# 0                           HYPONATRAEMIA
# 1  SUBACUTE CUTANEOUS LUPUS ERYTHEMATOSUS
# 2  BLOOD BILIRUBIN UNCONJUGATED INCREASED
# 3              TOXIC EPIDERMAL NECROLYSIS
# 4                             BRADYCARDIA
#
#                                        REPORTED_TERM    SOC_CODE  len
# 0                                       HYPONATREMIA  10027433.0    1
# 1  OMEPRAZOLE INDUCED SUBACUTE CUTANEOUS LUPUS ER...  10040785.0    4
# 2               INDIRECT BILIRUBIN (74.7 MICROMOL/L)  10022891.0    4
# 3                         TOXIC EPIDERMAL NECROLYSIS  10040785.0    3
# 4                                        BRADYCARDIA  10007541.0    1

# %%
MAX_WORDS = 26000
MAX_LEN = 40
EMBEDDING_DIM = 100

# %%
tokenizer = Tokenizer(num_words=MAX_WORDS, lower=True)

# %%
tokenizer.fit_on_texts(df_train.REPORTED_TERM)
sequences = tokenizer.texts_to_sequences(df_train.REPORTED_TERM)
x = pad_sequences(sequences, maxlen=MAX_LEN)

# %%
y = df_train.ART_CODE

# %%
dummies = pd.get_dummies(y.values)

# %%
y = np.array(dummies)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
NUM_CLASSES = y.shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, GlobalMaxPool1D, Dropout, SpatialDropout1D, LSTM
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %%
model = Sequential()
model.add(Embedding(MAX_WORDS, EMBEDDING_DIM, input_length=x.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(NUM_CLASSES, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

epochs = 30
batch_size = 64
# Out:
# WARNING:tensorflow:From /home/rahul/anaconda3/envs/deeplearning/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/rahul/anaconda3/envs/deeplearning/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.fit(
    x_train, y_train, 
    epochs=epochs, batch_size=batch_size,
    validation_data=[x_test, y_test],
    callbacks=[
        ReduceLROnPlateau(),
        EarlyStopping(monitor='val_loss', patience=10, min_delta=0.0001),
        ModelCheckpoint(filepath='model-LSTM.h5', save_best_only=True)])
# Out:
# WARNING:tensorflow:From /home/rahul/anaconda3/envs/deeplearning/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50586 samples, validate on 12647 samples
# Epoch 1/30
# 50586/50586 [==============================] - 97s 2ms/step - loss: 6.8541 - categorical_accuracy: 0.0429 - val_loss: 6.3248 - val_categorical_accuracy: 0.0682
# Epoch 2/30
# 50586/50586 [==============================] - 93s 2ms/step - loss: 5.8198 - categorical_accuracy: 0.1045 - val_loss: 5.4788 - val_categorical_accuracy: 0.1670
# Epoch 3/30
# 50586/50586 [==============================] - 96s 2ms/step - loss: 4.8265 - categorical_accuracy: 0.2402 - val_loss: 4.5971 - val_categorical_accuracy: 0.3251
# Epoch 4/30
# 50586/50586 [==============================] - 95s 2ms/step - loss: 3.9282 - categorical_accuracy: 0.3812 - val_loss: 3.9419 - val_categorical_accuracy: 0.4394
# Epoch 5/30
# 50586/50586 [==============================] - 94s 2ms/step - loss: 3.2451 - categorical_accuracy: 0.4794 - val_loss: 3.4952 - val_categorical_accuracy: 0.5148
# Epoch 6/30
# 50586/50586 [==============================] - 95s 2ms/step - loss: 2.7295 - categorical_accuracy: 0.5465 - val_loss: 3.1831 - val_categorical_accuracy: 0.5573
# Epoch 7/30
# 50586/50586 [==============================] - 92s 2ms/step - loss: 2.3243 - categorical_accuracy: 0.6036 - val_loss: 2.9474 - val_categorical_accuracy: 0.5937
# Epoch 8/30
# 50586/50586 [==============================] - 95s 2ms/step - loss: 2.0013 - categorical_accuracy: 0.6491 - val_loss: 2.7879 - val_categorical_accuracy: 0.6187
# Epoch 9/30
# 50586/50586 [==============================] - 95s 2ms/step - loss: 1.7347 - categorical_accuracy: 0.6850 - val_loss: 2.6703 - val_categorical_accuracy: 0.6380
# Epoch 10/30
# 50586/50586 [==============================] - 93s 2ms/step - loss: 1.5155 - categorical_accuracy: 0.7191 - val_loss: 2.5842 - val_categorical_accuracy: 0.6514
# Epoch 11/30
# 50586/50586 [==============================] - 94s 2ms/step - loss: 1.3266 - categorical_accuracy: 0.7467 - val_loss: 2.5176 - val_categorical_accuracy: 0.6613
# Epoch 12/30
# 50586/50586 [==============================] - 94s 2ms/step - loss: 1.1600 - categorical_accuracy: 0.7741 - val_loss: 2.4735 - val_categorical_accuracy: 0.6696
# Epoch 13/30
# 50586/50586 [==============================] - 91s 2ms/step - loss: 1.0242 - categorical_accuracy: 0.7967 - val_loss: 2.4315 - val_categorical_accuracy: 0.6808
# Epoch 14/30
# 50586/50586 [==============================] - 93s 2ms/step - loss: 0.9041 - categorical_accuracy: 0.8183 - val_loss: 2.4092 - val_categorical_accuracy: 0.6847
# Epoch 15/30
# 50586/50586 [==============================] - 92s 2ms/step - loss: 0.8031 - categorical_accuracy: 0.8361 - val_loss: 2.3896 - val_categorical_accuracy: 0.6901
# Epoch 16/30
# 50586/50586 [==============================] - 97s 2ms/step - loss: 0.7188 - categorical_accuracy: 0.8540 - val_loss: 2.3792 - val_categorical_accuracy: 0.6958
# Epoch 17/30
# 50586/50586 [==============================] - 94s 2ms/step - loss: 0.6412 - categorical_accuracy: 0.8681 - val_loss: 2.3741 - val_categorical_accuracy: 0.6965
# Epoch 18/30
# 50586/50586 [==============================] - 93s 2ms/step - loss: 0.5774 - categorical_accuracy: 0.8798 - val_loss: 2.3776 - val_categorical_accuracy: 0.6983
# Epoch 19/30
# 50586/50586 [==============================] - 92s 2ms/step - loss: 0.5274 - categorical_accuracy: 0.8881 - val_loss: 2.3692 - val_categorical_accuracy: 0.7013
# Epoch 20/30
# 50586/50586 [==============================] - 96s 2ms/step - loss: 0.4850 - categorical_accuracy: 0.8941 - val_loss: 2.3786 - val_categorical_accuracy: 0.7027
# Epoch 21/30
# 50586/50586 [==============================] - 95s 2ms/step - loss: 0.4416 - categorical_accuracy: 0.9025 - val_loss: 2.3831 - val_categorical_accuracy: 0.7031
# Epoch 22/30
# 50586/50586 [==============================] - 93s 2ms/step - loss: 0.4130 - categorical_accuracy: 0.9072 - val_loss: 2.3856 - val_categorical_accuracy: 0.7034
# Epoch 23/30
# 50586/50586 [==============================] - 94s 2ms/step - loss: 0.3835 - categorical_accuracy: 0.9136 - val_loss: 2.3944 - val_categorical_accuracy: 0.7058
# Epoch 24/30
# 50586/50586 [==============================] - 95s 2ms/step - loss: 0.3564 - categorical_accuracy: 0.9169 - val_loss: 2.3976 - val_categorical_accuracy: 0.7044
# Epoch 25/30
# 50586/50586 [==============================] - 93s 2ms/step - loss: 0.3392 - categorical_accuracy: 0.9196 - val_loss: 2.4059 - val_categorical_accuracy: 0.7066
# Epoch 26/30
# 50586/50586 [==============================] - 95s 2ms/step - loss: 0.3188 - categorical_accuracy: 0.9236 - val_loss: 2.4197 - val_categorical_accuracy: 0.7072
# Epoch 27/30
# 50586/50586 [==============================] - 96s 2ms/step - loss: 0.3027 - categorical_accuracy: 0.9247 - val_loss: 2.4181 - val_categorical_accuracy: 0.7081
# Epoch 28/30
# 50586/50586 [==============================] - 94s 2ms/step - loss: 0.2894 - categorical_accuracy: 0.9277 - val_loss: 2.4282 - val_categorical_accuracy: 0.7086
# Epoch 29/30
# 50586/50586 [==============================] - 97s 2ms/step - loss: 0.2760 - categorical_accuracy: 0.9304 - val_loss: 2.4405 - val_categorical_accuracy: 0.7088

# %%
def predict(reported_term):
    #tokenizer.fit_on_texts(reported_term)
    sequences = tokenizer.texts_to_sequences(reported_term)
    x = pad_sequences(sequences, maxlen=MAX_LEN)
    return x

# %%
input_text = predict(pd.Series("INSOMNIA"))

# %%
ypred = model.predict(input_text)

# %%
np.argmax(ypred)
# Out:
# 283

# %%
df_train[df_train.ART_CODE == 283]
# Out:
#        ART_CODE            DESC_CODED                   HLGT_NAME_COMPL  \
# 419         283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 619         283         Sleeplessness  SLEEP DISORDERS AND DISTURBANCES
# 1047        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 1302        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 1482        283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 1789        283   Difficulty sleeping  SLEEP DISORDERS AND DISTURBANCES
# 1844        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 3428        283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 4160        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 5867        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 6217        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 7052        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 7202        283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 8601        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 8959        283   Difficulty sleeping  SLEEP DISORDERS AND DISTURBANCES
# 9012        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 9464        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 10425       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 10579       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 10684       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 11879       283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 12529       283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 12737       283  insomnia exacerbated  SLEEP DISORDERS AND DISTURBANCES
# 13289       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 13869       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 14275       283       sleep decreased  SLEEP DISORDERS AND DISTURBANCES
# 14999       283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15658       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15718       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 17344       283       sleep decreased  SLEEP DISORDERS AND DISTURBANCES
# ...         ...                   ...                               ...
# 913         283       Sleep decreased  SLEEP DISORDERS AND DISTURBANCES
# 2005        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 4882        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 5070        283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 5517        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 6227        283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 7336        283   difficulty sleeping  SLEEP DISORDERS AND DISTURBANCES
# 8057        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 8070        283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 8302        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 8861        283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 9667        283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 10437       283       Sleep decreased  SLEEP DISORDERS AND DISTURBANCES
# 10529       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 11495       283         Sleeplessness  SLEEP DISORDERS AND DISTURBANCES
# 12092       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 12094       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 12474       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 12683       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 12999       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 13168       283         Sleeplessness  SLEEP DISORDERS AND DISTURBANCES
# 14579       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15343       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15348       283              insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15478       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15718       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15867       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 15916       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 18338       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
# 18791       283              Insomnia  SLEEP DISORDERS AND DISTURBANCES
#
#                                          HLT_NAME_COMPL    INC_CODE  \
# 419    DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 619    DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041017.0
# 1047   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 1302   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 1482   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041017.0
# 1789   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 1844   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 3428   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 4160   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 5867   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 6217   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 7052   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041001.0
# 7202   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 8601   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# 8959   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 9012   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# 9464   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 10425  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 10579  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 10684  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 11879  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 12529  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 12737  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022440.0
# 13289  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 13869  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 14275  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# 14999  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 15658  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 15718  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 17344  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# ...                                                 ...         ...
# 913    DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# 2005   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 4882   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 5070   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 5517   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041017.0
# 6227   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 7336   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 8057   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 8070   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 8302   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 8861   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 9667   DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 10437  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# 10529  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041001.0
# 11495  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041017.0
# 12092  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10012804.0
# 12094  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 12474  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 12683  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 12999  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# 13168  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041017.0
# 14579  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10041001.0
# 15343  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 15348  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 15478  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 15718  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 15867  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10040982.0
# 15916  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0
# 18338  DISTURBANCES IN INITIATING AND MAINTAINING SLEEP  10022437.0